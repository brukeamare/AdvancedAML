# %%
import numpy as np
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader

# %%
# Get gpu, mps or cpu device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2 = nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

def get_data_loaders(batch_size, augment=False):
    data_dir = './data'
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    train_transform = transforms.Compose([
        transforms.RandomResizedCrop(227) if augment else transforms.Resize(256),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(227),
        transforms.ToTensor(),
        normalize,
    ])

    test_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(227),
        transforms.ToTensor(),
        normalize,
    ])

    train_dataset = datasets.CIFAR10(root=data_dir, train=True, download=True, transform=train_transform)
    test_dataset = datasets.CIFAR10(root=data_dir, train=False, download=True, transform=test_transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
def train_and_evaluate(model, train_loader, test_loader, optimizer, criterion, scheduler, device, num_epochs, batch_size, learning_rate):
    best_accuracy = 0
    new_lr = learning_rate
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        temp=0
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            temp=temp+1
            if temp%100==0:
                print('train '+str(temp)+'/'+str(len(train_loader)))


            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        print(f'Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}')

        model.eval()
        correct = total = 0
        with torch.no_grad():
            tomp=0
            for images, labels in test_loader:

                tomp=tomp+1
                if tomp%100==0:
                    print('test '+str(tomp)+'/'+str(len(test_loader)))

                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total

        print(f'Accuracy on test set: {accuracy}%, Learining rate: {learning_rate}, Batch size: {batch_size}')
        if accuracy > best_accuracy:
            best_accuracy = accuracy




        scheduler.step(accuracy)

        if new_lr != learning_rate:
            new_lr = learning_rate

        # Print the last learing rate
        current_lr = scheduler.optimizer.param_groups[0]['lr']
        print(f'Learning rate: {current_lr}')

        if abs(accuracy) > 83.9:
            break


    return best_accuracy, new_lr

# %%
def obj_function(hyperparams):
    batch_size, learning_rate = hyperparams
    batch_size = int(batch_size)
    print(f'batch_size: {batch_size}, learning_rate: {learning_rate}')

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    train_loader, test_loader = get_data_loaders(batch_size)
    model = AlexNet(num_classes=10).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.005)
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.1, patience=10, verbose=True)

    num_epochs=10

    accuracy ,new_lr = train_and_evaluate(model, train_loader, test_loader, optimizer, criterion, scheduler, device, num_epochs, batch_size, learning_rate)

    return -accuracy , new_lr  # Negative accuracy for minimization

# %%
# PSO algorithm

def particle_swarm_optimization(num_dimensions, num_particles, max_iter, bounds, obj_function, w=0.5, c1=0.25, c2=0.75 , i_min=-10,i_max=10,):
    # Initialize the particles
    # This creates a data structure such as a dictionary
    if bounds is None:
        particles = [({'position': [np.random.uniform(i_min, i_max) for _ in range(num_dimensions)],
                    'velocity': [np.random.uniform(-1, 1) for _ in range(num_dimensions)],
                    'pbest': float('inf'),
                    'pbest_position': None})
                    for _ in range(num_particles)]
    else:
        particles = [({'position': [np.random.uniform(bounds[i][0], bounds[i][1]) for i in range(num_dimensions)],
                    'velocity': [np.random.uniform(-1, 1) for _ in range(num_dimensions)],
                    'pbest': float('inf'),
                    'pbest_position': None})
                    for _ in range(num_particles)]





    # Initialize global best
    gbest_value = float('inf')
    gbest_position = None

    for _ in range(max_iter):
        for particle in particles:


            position = particle['position']
            velocity = particle['velocity']

            print('position:',position)

            # Calculate the current value
            current_value , new_lr= obj_function(position)
            position[1] = new_lr

            # Update personal best
            if current_value < particle['pbest']:
                particle['pbest'] = current_value
                particle['pbest_position'] = position.copy()

            # Update global best
            if current_value < gbest_value:
                gbest_value = current_value
                gbest_position = position.copy()

            if abs(current_value) > 83.9:
                break

            # Update particle's velocity and position
            for i in range(num_dimensions):
                r1, r2 = np.random.uniform(), np.random.uniform()
                velocity[i] = w * velocity[i] + c1*r1 * (particle['pbest_position'][i] - position[i]) + c2*r2 * (gbest_position[i] - position[i])
                position[i] += velocity[i]
                # legalize the values to the provided bounds
                if bounds is not None:
                    position[i] = np.clip(position[i],bounds[i][0],bounds[i][1])

    return gbest_position, gbest_value

# %%
torch.cuda.empty_cache()

# %%
# PSO hyperparameters setup
num_dimensions = 2  # For example, batch_size and learning_rate
num_particles = 10
max_iter = 1
bounds = [(32, 45), (0.001, 0.01)]  # Example bounds for batch_size and learning_rate

torch.cuda.empty_cache()

# Run PSO
best_hyperparams, best_value = particle_swarm_optimization(num_dimensions, num_particles, max_iter, bounds, obj_function)

print("Best Hyperparameters:", best_hyperparams)

print("Best Validation Accuracy:", -best_value)
# Out:
# position: [43.74036540768514, 0.008260047204433463]
# batch_size: 43, learning_rate: 0.008260047204433463
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 1, Loss: 1.4850094857035478
# test 100/233
# test 200/233
# Accuracy on test set: 55.44%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 2, Loss: 1.0848590817209574
# test 100/233
# test 200/233
# Accuracy on test set: 66.14%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 3, Loss: 0.9117359105411112
# test 100/233
# test 200/233
# Accuracy on test set: 67.76%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 4, Loss: 0.8207167494122775
# test 100/233
# test 200/233
# Accuracy on test set: 66.45%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 5, Loss: 0.7631917113593603
# test 100/233
# test 200/233
# Accuracy on test set: 69.95%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 6, Loss: 0.7442539011417333
# test 100/233
# test 200/233
# Accuracy on test set: 62.24%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 7, Loss: 0.7172807396893243
# test 100/233
# test 200/233
# Accuracy on test set: 75.5%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 8, Loss: 0.7019031100865591
# test 100/233
# test 200/233
# Accuracy on test set: 73.67%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 9, Loss: 0.6893497580663971
# test 100/233
# test 200/233
# Accuracy on test set: 66.24%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# train 100/1163
# train 200/1163
# train 300/1163
# train 400/1163
# train 500/1163
# train 600/1163
# train 700/1163
# train 800/1163
# train 900/1163
# train 1000/1163
# train 1100/1163
# Epoch 10, Loss: 0.6764117241008263
# test 100/233
# test 200/233
# Accuracy on test set: 75.12%, Learining rate: 0.008260047204433463, Batch size: 43
# Learning rate: 0.008260047204433463
# position: [42.11667634332622, 0.002131872066721196]
# batch_size: 42, learning_rate: 0.002131872066721196
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 1, Loss: 1.4081094779455792
# test 100/239
# test 200/239
# Accuracy on test set: 60.6%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 2, Loss: 0.9906940537525964
# test 100/239
# test 200/239
# Accuracy on test set: 67.53%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 3, Loss: 0.8304865624752493
# test 100/239
# test 200/239
# Accuracy on test set: 72.24%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 4, Loss: 0.7337410017335044
# test 100/239
# test 200/239
# Accuracy on test set: 76.5%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 5, Loss: 0.6741981233347373
# test 100/239
# test 200/239
# Accuracy on test set: 77.57%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 6, Loss: 0.6192309326428911
# test 100/239
# test 200/239
# Accuracy on test set: 76.55%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 7, Loss: 0.5823495151814445
# test 100/239
# test 200/239
# Accuracy on test set: 80.06%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 8, Loss: 0.5556975481992604
# test 100/239
# test 200/239
# Accuracy on test set: 78.96%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 9, Loss: 0.5236976054363347
# test 100/239
# test 200/239
# Accuracy on test set: 79.84%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# train 100/1191
# train 200/1191
# train 300/1191
# train 400/1191
# train 500/1191
# train 600/1191
# train 700/1191
# train 800/1191
# train 900/1191
# train 1000/1191
# train 1100/1191
# Epoch 10, Loss: 0.5018607799892761
# test 100/239
# test 200/239
# Accuracy on test set: 81.36%, Learining rate: 0.002131872066721196, Batch size: 42
# Learning rate: 0.002131872066721196
# position: [32.19600353050967, 0.0030302377383245554]
# batch_size: 32, learning_rate: 0.0030302377383245554
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 1, Loss: 1.4315476424405762
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 59.41%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 2, Loss: 1.0199876238883343
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.29%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 3, Loss: 0.8546831205687458
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 71.21%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 4, Loss: 0.7660913048496784
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 71.95%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 5, Loss: 0.6979306466634352
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 74.31%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 6, Loss: 0.6519007555239489
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 78.31%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 7, Loss: 0.6060337518852488
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 77.21%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 8, Loss: 0.5758506924161831
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 76.74%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 9, Loss: 0.5567834779705974
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 79.37%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 10, Loss: 0.5426044842217568
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 78.67%, Learining rate: 0.0030302377383245554, Batch size: 32
# Learning rate: 0.0030302377383245554
# position: [32.31238719493934, 0.007499632701900346]
# batch_size: 32, learning_rate: 0.007499632701900346
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 1, Loss: 1.5040664238496537
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 55.58%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 2, Loss: 1.1046129772088045
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 59.93%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 3, Loss: 0.9236814268910573
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 61.73%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 4, Loss: 0.8465058045820479
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.36%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 5, Loss: 0.8058440485446025
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.96%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 6, Loss: 0.7877536599291339
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 61.7%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 7, Loss: 0.765902176337294
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 70.74%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 8, Loss: 0.7519747803627644
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.03%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 9, Loss: 0.741272459446583
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 70.13%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 10, Loss: 0.7298406111702123
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 69.96%, Learining rate: 0.007499632701900346, Batch size: 32
# Learning rate: 0.007499632701900346
# position: [37.88999708182367, 0.007866401995711678]
# batch_size: 37, learning_rate: 0.007866401995711678
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 1, Loss: 1.483741131363183
# test 100/271
# test 200/271
# Accuracy on test set: 54.37%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 2, Loss: 1.099069298239502
# test 100/271
# test 200/271
# Accuracy on test set: 66.34%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 3, Loss: 0.9157098377200626
# test 100/271
# test 200/271
# Accuracy on test set: 64.93%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 4, Loss: 0.8253971768554146
# test 100/271
# test 200/271
# Accuracy on test set: 70.06%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 5, Loss: 0.7848500258691565
# test 100/271
# test 200/271
# Accuracy on test set: 65.36%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 6, Loss: 0.7636623552961815
# test 100/271
# test 200/271
# Accuracy on test set: 75.55%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 7, Loss: 0.7378378433544608
# test 100/271
# test 200/271
# Accuracy on test set: 66.03%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 8, Loss: 0.7315318496600234
# test 100/271
# test 200/271
# Accuracy on test set: 57.38%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 9, Loss: 0.7119631969188092
# test 100/271
# test 200/271
# Accuracy on test set: 70.09%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 10, Loss: 0.7046235052967919
# test 100/271
# test 200/271
# Accuracy on test set: 75.25%, Learining rate: 0.007866401995711678, Batch size: 37
# Learning rate: 0.007866401995711678
# position: [33.25935535772609, 0.004370270204361516]
# batch_size: 33, learning_rate: 0.004370270204361516
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 1, Loss: 1.4173962007569134
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 51.57%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 2, Loss: 1.0315319945676975
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 63.04%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 3, Loss: 0.8695405080206791
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 66.08%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 4, Loss: 0.7888849568319823
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 72.71%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 5, Loss: 0.7254964205139073
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 74.74%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 6, Loss: 0.6799222107848895
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 71.56%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 7, Loss: 0.6507145023676211
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 73.47%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 8, Loss: 0.6328602527074103
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 78.23%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 9, Loss: 0.6141045287762594
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 79.74%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 10, Loss: 0.5990889530854993
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 75.32%, Learining rate: 0.004370270204361516, Batch size: 33
# Learning rate: 0.004370270204361516
# position: [32.57652119073978, 0.006059134349333108]
# batch_size: 32, learning_rate: 0.006059134349333108
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 1, Loss: 1.469566993963543
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 49.86%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 2, Loss: 1.070138126135025
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 68.77%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 3, Loss: 0.8951838505207081
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.61%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 4, Loss: 0.8091524881540165
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 73.27%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 5, Loss: 0.7616285674002258
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 72.28%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 6, Loss: 0.735282741339254
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 72.8%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 7, Loss: 0.7132696634252638
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 71.8%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 8, Loss: 0.6966058508905935
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 71.39%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 9, Loss: 0.6818416020996816
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 66.5%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 10, Loss: 0.6693220346574973
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 77.46%, Learining rate: 0.006059134349333108, Batch size: 32
# Learning rate: 0.006059134349333108
# position: [37.56666958921355, 0.0018948271170725363]
# batch_size: 37, learning_rate: 0.0018948271170725363
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 1, Loss: 1.3984965221328143
# test 100/271
# test 200/271
# Accuracy on test set: 59.65%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 2, Loss: 0.9799841137371472
# test 100/271
# test 200/271
# Accuracy on test set: 68.57%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 3, Loss: 0.8243108965103796
# test 100/271
# test 200/271
# Accuracy on test set: 72.91%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 4, Loss: 0.7348493565777703
# test 100/271
# test 200/271
# Accuracy on test set: 76.83%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 5, Loss: 0.6725513601245788
# test 100/271
# test 200/271
# Accuracy on test set: 78.5%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 6, Loss: 0.6221961249547774
# test 100/271
# test 200/271
# Accuracy on test set: 77.71%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 7, Loss: 0.5827669340389721
# test 100/271
# test 200/271
# Accuracy on test set: 78.08%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 8, Loss: 0.5512362351784339
# test 100/271
# test 200/271
# Accuracy on test set: 80.18%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 9, Loss: 0.5234962194584883
# test 100/271
# test 200/271
# Accuracy on test set: 77.81%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# train 100/1352
# train 200/1352
# train 300/1352
# train 400/1352
# train 500/1352
# train 600/1352
# train 700/1352
# train 800/1352
# train 900/1352
# train 1000/1352
# train 1100/1352
# train 1200/1352
# train 1300/1352
# Epoch 10, Loss: 0.4946826713809953
# test 100/271
# test 200/271
# Accuracy on test set: 80.2%, Learining rate: 0.0018948271170725363, Batch size: 37
# Learning rate: 0.0018948271170725363
# position: [32.42922248595724, 0.009875771124586184]
# batch_size: 32, learning_rate: 0.009875771124586184
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 1, Loss: 1.5392478957286038
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 54.47%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 2, Loss: 1.1428643130218838
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 48.77%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 3, Loss: 0.975886146189384
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 67.01%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 4, Loss: 0.9235916929182454
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 65.93%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 5, Loss: 0.8830969024947722
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 68.46%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 6, Loss: 0.8565234707969926
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 62.8%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 7, Loss: 0.8378469831121327
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 62.26%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 8, Loss: 0.831274949409835
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 70.51%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 9, Loss: 0.8214821733882316
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 71.28%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# train 100/1563
# train 200/1563
# train 300/1563
# train 400/1563
# train 500/1563
# train 600/1563
# train 700/1563
# train 800/1563
# train 900/1563
# train 1000/1563
# train 1100/1563
# train 1200/1563
# train 1300/1563
# train 1400/1563
# train 1500/1563
# Epoch 10, Loss: 0.8173874209343587
# test 100/313
# test 200/313
# test 300/313
# Accuracy on test set: 60.35%, Learining rate: 0.009875771124586184, Batch size: 32
# Learning rate: 0.009875771124586184
# position: [33.38644633375932, 0.004092094423906241]
# batch_size: 33, learning_rate: 0.004092094423906241
# Files already downloaded and verified
# Files already downloaded and verified
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 1, Loss: 1.4163684353507604
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 57.27%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 2, Loss: 1.0214766151515036
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 66.53%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 3, Loss: 0.860925162432219
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 65.91%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 4, Loss: 0.7676422866872245
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 72.97%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 5, Loss: 0.7103205005734137
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 75.33%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 6, Loss: 0.663333950048229
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 75.24%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 7, Loss: 0.6295366419729898
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 75.57%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 8, Loss: 0.618229475747155
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 76.94%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 9, Loss: 0.5950130927315016
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 73.25%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# train 100/1516
# train 200/1516
# train 300/1516
# train 400/1516
# train 500/1516
# train 600/1516
# train 700/1516
# train 800/1516
# train 900/1516
# train 1000/1516
# train 1100/1516
# train 1200/1516
# train 1300/1516
# train 1400/1516
# train 1500/1516
# Epoch 10, Loss: 0.5856066891299389
# test 100/304
# test 200/304
# test 300/304
# Accuracy on test set: 77.78%, Learining rate: 0.004092094423906241, Batch size: 33
# Learning rate: 0.004092094423906241
# Best Hyperparameters: [42.11667634332622, 0.002131872066721196]
# Best Validation Accuracy: 81.36

# %% [markdown]
# # batch size: 42
# # learnign rate: 0.002131872066721196
# # Accuracy: 81.36

# %% [markdown]
# # 3. Posted on Githib at: https://brukeamare.github.io/AdvancedAML/Amare_HW2.html
